# %% [markdown]
# # Day 002: The Dot Product (Scalar Product)

# %% [markdown]
# ## 1. Objective
# The **Dot Product** is the engine of similarity and reduction in linear algebra. Unlike element-wise operations (Addition, Hadamard) that return a new vector, the dot product takes two vectors of equal length collapses them into a **single scalar number**.

# %% [markdown]
# ## 2. Mathematical Foundation
# > *(Define the variables and write the equation using LaTeX here)*
#
# **Example:**
# $$ A \cdot B = \sum_{i=1}^{n} A_i B_i $$

# %% [markdown]
# ## 3. Algorithmic Strategy
# > *(Bullet points explaining how you will translate the math into arrays and loops)*

# %% [markdown]
# ## 4. Implementation

# %%
import numpy as np

# Write your raw Python/NumPy code here

# %% [markdown]
# ## 5. Verification

# %%
# Write a small test block proving your scratch code works
# Compare it against a known mathematical outcome if possible
